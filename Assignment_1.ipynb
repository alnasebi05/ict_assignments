# %% [markdown]
# <a href="https://colab.research.google.com/github/alnasebi05/ict_assignments/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment 1
#Question 1
'''item 1 price = 45
item 1 quantity = 3
item 2 price = 30
item 2 quantity = 2'''
item_1_price = 45
item_1_quantity = 3
item_2_price = 30
item_2_quantity = 2

total = item_1_price * item_1_quantity + item_2_price * item_2_quantity
print('Total bill :',total)
# Out:
# Total bill : 195

# %%
#Question 2
'''Enter temperature in Celsius = 30'''
Enter_temperature_in_Celsius = 30
C = 30
F = (C * 9/5)+32
print('Temperature in Fahrenheit :',F)
# Out:
# Temperature in Fahrenheit : 86.0

# %%
#Question 3
'''Enter basic salary = 20000'''
Basic_salary = 20000
total = Basic_salary + Basic_salary * 20/100 + Basic_salary * 10/100
print('Net salary :',total)
# Out:
# Net salary : 26000.0

# %%
#Question 4
'''Principal : 10000
Rate of interest : 5
Time (in years) : 2'''
P = 10000
R = 5
T = 2
SI = (P * R * T)/100
print('Simple interest:',SI)
# Out:
# Simple interest: 1000.0

# %%
#Question 5
total_minutes = 130
hours = total_minutes // 60
minutes = total_minutes % 60
print(hours,'hours and',minutes,'Minutes')
# Out:
# 2 hours and 10 Minutes

# %%
#Question 6
#BMI = weight(kg) / (height(m) * height(m))
weight = 60
height = 1.65
bmi = weight / (height * height)
print('BMI :',bmi)
# Out:
# BMI : 22.03856749311295

# %%
#Question 7
#Original price : 1200
Original_price = 1200
discount_price = Original_price - Original_price * 10/100
print('Discounted price :',discount_price)
# Out:
# Discounted price : 1080.0

# %%
#Question 8
''' s = (a+b+c) / 2
Area = sqrt(s * (s - a)(s - b)(s - c))'''
a = 5
b = 6
c = 7
s = (a+b+c)/2
import math
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print('Area of the triangle',area)
# Out:
# Area of the triangle 14.696938456699069

# %%
#Question 9
'''wall length : 12
wall height : 8'''
area = (12 * 8) - (2 * (1.5 * 1.2))
cost = area * 25
print('Total area to be painted :', area)
print('Total painting cost :',cost)
# Out:
# Total area to be painted : 92.4
# Total painting cost : 2310.0

# %%
# Question 10
'''Enter number of units consumed : 250'''
units = 250
bill = (units * 5.2 ) + 100
print('Electricity bill :',bill)
# Out:
# Electricity bill : 1400.0
