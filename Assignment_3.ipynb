# %% [markdown]
# <a href="https://colab.research.google.com/github/alnasebi05/ict_assignments/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment 3
# Question 1
def maximum(a,b,c):
  if a>b and a>c:
    print(a, 'is maximum')
  elif b>a and b>c:
    print(b, 'is maximum')
  else:
    print(c, 'is maximum')

a = int(input ('Enter first number: '))
b = int(input ('Enter second number: '))
c = int(input ('Enter third number: '))
maximum(a,b,c)
# Out:
# Enter first number: 76
# Enter second number: 77
# Enter third number: 909
# 909 is maximum

# %%
# Question 2
# list = [18,12,30,10,7]
list = [18,12,30,10,7]
sum(list)
# Out:
# 77

# %%
#Question 3
list = [10,20,30,50]
list.insert(3,40)
list
# Out:
# [10, 20, 30, 40, 50]

# %%
#Question 4
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
sample_dict['location'] = sample_dict.pop('city')
print(sample_dict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %%
#Question 5
sample_dict = {
 'emp1': {'name': 'Jhon', 'salary': 7500},
 'emp2': {'name': 'Emma', 'salary': 8000},
 'emp3': {'name': 'Brad', 'salary': 500}
}
sample_dict['emp3']['salary'] = 8500
sample_dict
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500},
#  'emp2': {'name': 'Emma', 'salary': 8000},
#  'emp3': {'name': 'Brad', 'salary': 8500}}

# %%
#Question 6
tuple1 = (11, 22, 33, 44, 55, 66)
new_tuple = tuple1[3:5]
print(new_tuple)
# Out:
# (44, 55)

# %%
#Question 7
tuple1 = (50, 10, 60, 70, 50,83,567,50,81)
tuple1.count(50)
# Out:
# 3
